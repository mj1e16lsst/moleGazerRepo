# %% [markdown]
# # Preamble

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg
from matplotlib.patches import Ellipse,Rectangle
import palettable.colorbrewer as pc

from astropy.stats import sigma_clipped_stats
from astropy.io import fits
from photutils import datasets
from photutils import DAOStarFinder
from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
from photutils import CircularAperture

from cycler import cycler
plt.rcParams["axes.prop_cycle"]=cycler('color',pc.qualitative.Set3_12.mpl_colors)

# %matplotlib inline

def plot_moles(FIG,AX,SRCS):
    positions = (SRCS['xcentroid'], SRCS['ycentroid'])
    apertures = CircularAperture(positions, r=50)
    norm = ImageNormalize(stretch=SqrtStretch())
    im=AX.imshow(data, cmap='Greys', origin='lower', norm=norm)
#     ax.set_aspect(0.5)
    apertures.plot(color='C0', lw=3., alpha=0.5)

#     cax = FIG.add_axes([1., 0.14, 0.1, 0.79]) ## [x0,y0,width,height]
#     fig.colorbar(im,cax=cax)
    # print(apertures)

    rect = Rectangle((500,1000),1500,2000,linewidth=5,ls="--",edgecolor='r',facecolor='none') ## xy, width, height
    AX.add_patch(rect)

    AX.set_xticks(range(0,2500,500))
    AX.set_xlabel(r"$x\,/\,{\rm Pixels}$",fontsize=50)
    AX.set_ylabel(r"$y\,/\,{\rm Pixels}$",fontsize=50)

def find_sources(DATA):
    mask_y=[1000,3000]
    mask_x=[500,2000]
    mask = np.ones_like(DATA, dtype=bool)
    # mask[mask_y[0]:mask_y[1],mask_x[0]:mask_x[1]] = False
    mean,median,std=sigma_clipped_stats(DATA,sigma=2.0)    

    daofind = DAOStarFinder(fwhm=10.0, threshold=5.*std)#,sigma_radius=2)#,roundlo=0.1)    
    SOURCES = daofind(DATA-median,mask=mask)    
    for col in SOURCES.colnames:    
        SOURCES[col].info.format = '%.5g'  # for consistent table output
    print(SOURCES)
    return SOURCES

def get_smooth_dist(y,lim="L"):
    if lim=="L":
        MIN,MAX=38.,46.
    else:
        MIN,MAX=3.,251.
    density=ss.gaussian_kde(y)
#     ys = np.linspace(np.min(y)/1.1,np.max(y)*1.1,200)
    ys = np.linspace(MIN,MAX,200)
    density.covariance_factor = lambda : .25
    density._compute_covariance()
    
    dens=density(ys)
    normed=dens/np.max(dens)
    return normed,ys


def plot_key(fig,ax_key,data):
    ax_key.scatter(data,data,label=r"${\bf DATA}$" %locals(),marker=".",facecolor="0.6",edgecolor="none",linewidth=4.,s=500,zorder=-10**8,alpha=1.)
    ax_key.set_xlim([0.,1.])
    ax_key.set_ylim(ax_key.get_xlim())
    leg=ax_key.legend(loc="lower center",framealpha=0.,fontsize=50.,handletextpad=0.1,labelspacing=.5,bbox_to_anchor=(0.35,-0.05))

    cols=["0.6","C0","C2","C3"]
    for i,txt in enumerate(leg.get_texts()):
        txt.set_color(cols[i])

# %% [markdown]
# ## Creating mole dataframe

# %% [markdown]
# For code used in region filenames:
# FILENAME == regions_NN.reg
#
# - "NN": from "01" -- "14": position used from Mole Screen protocol
#  - 15 or 16: added to represent looking down over the left and right shoulders, respectively
#  - "FOOT": Foot
#  - "FACE": Face
#  - if "Z" present, then Zoom in on NN view
#  - if "D", image is Dermoscopy
#
# Next step is to add to dataframe parameters for images with:
# - "R"/"NR": Removed or Not Removed (surgically)
# - "S"/"NS": "Scale"/"No Scale": scale/ruler present on image (excluding hairlines in some dermoscopy images)
# - "A"/"NA": "Arrow"(s)/"No Arrow"(s): arrow drawn on patient

# %%
from regions import read_ds9, write_ds9
from astropy.io import fits
import matplotlib.image as mpimg
import glob
from shutil import copyfile
import pandas as pd

## where to store the fits files
data_path=os.getcwd()+"/0_PATIENT_DATA/"   
    
mole_df=pd.DataFrame(columns=["MOLE_ID",
                              "PATIENT",
                              "PHOTO",
                              "REG_RADIUS_PIXELS",
                              "REG_XCENTER_PIXELS",
                              "REG_YCENTER_PIXELS",
                              "PATIENT_VIEW",
                              "OBS_DATE"])

patient_paths=sorted(glob.glob(data_path+"/*"))
patients=[pat_path.split(data_path)[-1] for pat_path in patient_paths]

for i,patient_path in enumerate(patient_paths):
    patient=patients[i]
    print("PATIENT: "+str(patient))
    
    patient_photo_paths=sorted(glob.glob(patient_path+"/*"))
    patient_photos=[pat_phot_path.split("/"+patient+"/")[-1] for pat_phot_path in patient_photo_paths]
    
    for j,patient_photo_path in enumerate(patient_photo_paths):
        patient_photo=patient_photos[j]
        
        region_paths=glob.glob(patient_photo_path+"/"+patient_photo+"regions/*")
        regions=[reg_path.split("regions/")[-1] for reg_path in region_paths]
        body_positions=[reg.split("_")[-1].split(".reg")[0] for reg in regions]
        
        for k,region_path in enumerate(region_paths):
            region=regions[k]
            body_position=body_positions[k]
            R=read_ds9(region_path)
            
            for l,REGION in enumerate(R):
                MOLE_ID=str(patient)+"_"+str(patient_photo)+"_POS"+str(body_position)+"_"+str(int(l+1))
                temp=pd.DataFrame(data={"MOLE_ID":MOLE_ID,
                                        "PATIENT":patient,
                                        "PHOTO":patient_photo,
                                        "REG_RADIUS_PIXELS":REGION.radius,
                                        "REG_XCENTER_PIXELS":REGION.center.x,
                                        "REG_YCENTER_PIXELS":REGION.center.y,
                                        "PATIENT_VIEW":body_position,
                                        "OBS_DATE":"NaN"},index=[0])
                mole_df=mole_df.append(temp,ignore_index=True)

        
print(mole_df.head())
# Out:
# PATIENT: 0_MASTER_MOLES.csv
# PATIENT: A
# PATIENT: B
# PATIENT: C
# PATIENT: D
# PATIENT: E
# PATIENT: F
# PATIENT: G
# PATIENT: H
# PATIENT: I
# PATIENT: J
# PATIENT: K
# PATIENT: L
# PATIENT: M
# PATIENT: MOLE_PHOTOMETRY
# PATIENT: N
# PATIENT: O
# PATIENT: P
# PATIENT: Q
# PATIENT: R
# PATIENT: S
#            MOLE_ID PATIENT  PHOTO  REG_RADIUS_PIXELS  REG_XCENTER_PIXELS  \
# 0  A_30536_POS02_1       A  30536          60.735346           1083.1920
# 1  A_30536_POS02_2       A  30536          24.238328           1049.7081
# 2  A_30536_POS02_3       A  30536          18.615205           1140.1920
# 3  A_30536_POS02_4       A  30536          24.238328           1209.2160
# 4  A_30536_POS02_5       A  30536          24.238328           2300.9548
#
#    REG_YCENTER_PIXELS PATIENT_VIEW OBS_DATE
# 0           2676.5440           02      NaN
# 1           1326.3129           02      NaN
# 2           2312.5440           02      NaN
# 3           3122.6112           02      NaN
# 4           2216.3750           02      NaN

# %%
print((mole_df.loc[mole_df.REG_RADIUS_PIXELS==0.]))
print(len(mole_df))
# mole_df.to_csv("/Users/pboorman/Desktop/mole_df.csv")
# Out:
# Empty DataFrame
# Columns: [MOLE_ID, PATIENT, PHOTO, REG_RADIUS_PIXELS, REG_XCENTER_PIXELS, REG_YCENTER_PIXELS, PATIENT_VIEW, OBS_DATE]
# Index: []
# 4009

# %% [markdown]
# # Extracting photometry for each mole

# %% [markdown]
# Going to link everything FROM the dataframe as a starting point.
#
# This code is quite clunky, but works if there is a clear difference between the mole and skin pixel distributions in r g and b.

# %%
## first check that leading zeros have not been removed on the photo filenames which require them!
data_path="/Users/pboorman/Dropbox/1_work/9_projects/9p_molegazer/0_PATIENT_DATA/"   
mole_df=pd.read_csv(data_path+"/0_MASTER_MOLES.csv",converters={'PHOTO': lambda x: str(x)})

## patient E photofilenames all have leading zeros
print(mole_df.loc[mole_df.PATIENT=="E"])
# Out:
#      SCRIPT_ID              MOLE_ID PATIENT     PHOTO  REG_RADIUS_PIXELS  \
# 513        513   E_00174987_POS01_1       E  00174987          13.217083
# 514        514   E_00174987_POS01_2       E  00174987          12.903616
# 515        515   E_00174987_POS01_3       E  00174987          17.704148
# 516        516   E_00174987_POS01_4       E  00174987          17.785755
# 517        517   E_00174987_POS01_5       E  00174987          17.935451
# 518        518   E_00174987_POS01_6       E  00174987          10.096859
# 519        519   E_00174987_POS01_7       E  00174987          11.372840
# 520        520   E_00174987_POS01_8       E  00174987          15.439722
# 521        521   E_00174988_POS02_1       E  00174988          21.863241
# 522        522   E_00174988_POS02_2       E  00174988          22.730335
# 523        523   E_00174988_POS02_3       E  00174988          27.203983
# 524        524   E_00174988_POS02_4       E  00174988          28.702468
# 525        525   E_00174988_POS02_5       E  00174988          18.969227
# 526        526   E_00174989_POS16_1       E  00174989          16.082104
# 527        527   E_00174989_POS16_2       E  00174989          12.974275
# 528        528   E_00174989_POS16_3       E  00174989          17.712997
# 529        529   E_00174989_POS16_4       E  00174989          15.380866
# 530        530   E_00174989_POS16_5       E  00174989          18.515927
# 531        531   E_00174989_POS16_6       E  00174989          13.027628
# 532        532   E_00174990_POS03_1       E  00174990          20.000087
# 533        533   E_00174990_POS03_2       E  00174990          15.209511
# 534        534   E_00174990_POS03_3       E  00174990          15.484140
# 535        535   E_00174990_POS03_4       E  00174990          12.731611
# 536        536   E_00174990_POS03_5       E  00174990          13.160664
# 537        537   E_00174991_POS15_1       E  00174991          15.873497
# 538        538   E_00174991_POS15_2       E  00174991          13.514513
# 539        539   E_00174991_POS15_3       E  00174991          12.441183
# 540        540   E_00174991_POS15_4       E  00174991          15.403545
# 541        541   E_00174991_POS15_5       E  00174991          17.488743
# 542        542   E_00174991_POS15_6       E  00174991          12.490078
# ..         ...                  ...     ...       ...                ...
# 555        555   E_00174993_POS09_4       E  00174993          18.482005
# 556        556   E_00174994_POS11_1       E  00174994          17.661649
# 557        557   E_00174994_POS11_2       E  00174994          13.237525
# 558        558   E_00174995_POS12_1       E  00174995          12.896037
# 559        559   E_00174995_POS12_2       E  00174995          18.058985
# 560        560   E_00174995_POS12_3       E  00174995          13.419346
# 561        561   E_00174995_POS12_4       E  00174995          15.454625
# 562        562   E_00174995_POS12_5       E  00174995          12.130415
# 563        563   E_00174995_POS12_6       E  00174995          14.971418
# 564        564   E_00174995_POS12_7       E  00174995          13.824437
# 565        565   E_00174995_POS12_8       E  00174995          22.964510
# 566        566   E_00174995_POS12_9       E  00174995          18.240650
# 567        567   E_00174996_POS10_1       E  00174996          15.871235
# 568        568   E_00174996_POS10_2       E  00174996          11.854983
# 569        569   E_00174996_POS10_3       E  00174996          12.477538
# 570        570   E_00174996_POS10_4       E  00174996          11.602175
# 571        571   E_00174996_POS10_5       E  00174996          12.243481
# 572        572   E_00174996_POS10_6       E  00174996          14.643744
# 573        573   E_00174996_POS10_7       E  00174996          17.626841
# 574        574   E_00174996_POS10_8       E  00174996          15.223030
# 575        575   E_00174996_POS10_9       E  00174996          13.220811
# 576        576  E_00174996_POS10_10       E  00174996          20.093237
# 577        577  E_00174996_POS10_11       E  00174996          19.282004
# 578        578  E_00174996_POS10_12       E  00174996          11.028529
# 579        579   E_00174997_POS05_1       E  00174997          11.649238
# 580        580   E_00174997_POS05_2       E  00174997           9.832749
# 581        581   E_00174997_POS05_3       E  00174997          15.484317
# 582        582   E_00174997_POS05_4       E  00174997          11.339045
# 583        583   E_00174997_POS05_5       E  00174997           7.827941
# 584        584   E_00174997_POS05_6       E  00174997          12.128436
#
#      REG_XCENTER_PIXELS  REG_YCENTER_PIXELS REG_SHAPE PATIENT_VIEW    OBS_DATE
# 513              905.00             2810.00    CIRCLE            1  10/10/2012
# 514             1129.00             2837.00    CIRCLE            1  10/10/2012
# 515             1791.00             1224.00    CIRCLE            1  10/10/2012
# 516             1111.00             1729.00    CIRCLE            1  10/10/2012
# 517             1604.00             1890.00    CIRCLE            1  10/10/2012
# 518              614.00              994.00    CIRCLE            1  10/10/2012
# 519             1894.00             1454.00    CIRCLE            1  10/10/2012
# 520             1828.00             1746.00    CIRCLE            1  10/10/2012
# 521             1245.88             2413.72    CIRCLE            2  10/10/2012
# 522             1325.84             3301.52    CIRCLE            2  10/10/2012
# 523              585.68             3092.72    CIRCLE            2  10/10/2012
# 524             1037.84             2788.88    CIRCLE            2  10/10/2012
# 525              150.80             3238.16    CIRCLE            2  10/10/2012
# 526              779.00             3091.00    CIRCLE           16  10/10/2012
# 527              564.00             2953.00    CIRCLE           16  10/10/2012
# 528              564.00             1851.00    CIRCLE           16  10/10/2012
# 529              593.00             1327.00    CIRCLE           16  10/10/2012
# 530             1331.00              937.00    CIRCLE           16  10/10/2012
# 531             1332.00              975.00    CIRCLE           16  10/10/2012
# 532             1393.44             1079.80    CIRCLE            3  10/10/2012
# 533             1392.00             1120.12    CIRCLE            3  10/10/2012
# 534             1475.52             1143.16    CIRCLE            3  10/10/2012
# 535              826.96             2255.84    CIRCLE            3  10/10/2012
# 536              880.24             2250.08    CIRCLE            3  10/10/2012
# 537             1500.00             1918.00    CIRCLE           15  10/10/2012
# 538             1482.00             3565.00    CIRCLE           15  10/10/2012
# 539             1523.00             3609.00    CIRCLE           15  10/10/2012
# 540              533.00             2273.00    CIRCLE           15  10/10/2012
# 541              577.00             1651.00    CIRCLE           15  10/10/2012
# 542              929.00             1357.00    CIRCLE           15  10/10/2012
# ..                  ...                 ...       ...          ...         ...
# 555              401.00              210.00    CIRCLE            9  10/10/2012
# 556              235.00             1205.00    CIRCLE           11  10/10/2012
# 557              274.00             2277.00    CIRCLE           11  10/10/2012
# 558              432.00             3757.00    CIRCLE           12  10/10/2012
# 559              559.00             3096.00    CIRCLE           12  10/10/2012
# 560              526.00             2447.00    CIRCLE           12  10/10/2012
# 561              562.00             2447.00    CIRCLE           12  10/10/2012
# 562              801.00             2409.00    CIRCLE           12  10/10/2012
# 563              853.00             2704.00    CIRCLE           12  10/10/2012
# 564              865.00             2466.00    CIRCLE           12  10/10/2012
# 565              463.00             1467.00    CIRCLE           12  10/10/2012
# 566              555.00              686.00    CIRCLE           12  10/10/2012
# 567              331.00             3003.00    CIRCLE           10  10/10/2012
# 568              725.00             3781.00    CIRCLE           10  10/10/2012
# 569              909.00             3757.00    CIRCLE           10  10/10/2012
# 570              116.00             2428.00    CIRCLE           10  10/10/2012
# 571              225.00             2541.00    CIRCLE           10  10/10/2012
# 572              175.00             2442.00    CIRCLE           10  10/10/2012
# 573              443.00              818.00    CIRCLE           10  10/10/2012
# 574              239.00              935.00    CIRCLE           10  10/10/2012
# 575              206.00              623.00    CIRCLE           10  10/10/2012
# 576              204.00              537.00    CIRCLE           10  10/10/2012
# 577              392.00              338.00    CIRCLE           10  10/10/2012
# 578              403.00              502.00    CIRCLE           10  10/10/2012
# 579              994.00             3185.00    CIRCLE            5  10/10/2012
# 580             1663.00             2946.00    CIRCLE            5  10/10/2012
# 581             1790.00             1481.00    CIRCLE            5  10/10/2012
# 582             1865.00             2792.00    CIRCLE            5  10/10/2012
# 583             1872.00             2813.00    CIRCLE            5  10/10/2012
# 584              948.00             2816.00    CIRCLE            5  10/10/2012
#
# [72 rows x 10 columns]

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from regions import read_ds9,write_ds9,PixCoord,BoundingBox
from astropy.io import fits
from astropy.stats import SigmaClip

import palettable.colorbrewer as pc
from cycler import cycler
plt.rcParams["axes.prop_cycle"]=cycler('color',pc.qualitative.Set3_12.mpl_colors)
# %matplotlib inline

from scipy.optimize import curve_fit
from astropy.stats import SigmaClip
from collections import OrderedDict
from astropy.coordinates import Angle, SkyCoord
from regions import PixCoord, CirclePixelRegion



def gauss_x2(x, *p):
    a1, b1, c1, d1, a2, b2, c2, d2=p
    y = a1*np.exp(-np.power((x - b1), 2.)/(2. * c1**2.)) +a2*np.exp(-np.power((x - b2), 2.)/(2. * c2**2.))# + d1+ d2
    return y

def gauss_x1(x, *p):
    a1, b1, c1, d1=p
    y = a1*np.exp(-np.power((x - b1), 2.)/(2. * c1**2.))# + d1
    return y


def FIT_GAUSSIAN(X,Y):#,AX,PLOT_LEG):
#     fig,ax1=plt.subplots(figsize=(15,12))
    #     [amplitude, mean, sigma, vertical normalisation]
    PEAK_initial = [np.median(Y), int((np.max(X)-np.min(X))/3.+np.min(X)), 4., 0.,
                    np.median(Y), X[np.argmax(Y)], 4., 0.]
    try:
        popt,pcov=curve_fit(gauss_x2, X, Y, p0=PEAK_initial,maxfev=1000)#, bounds=param_bounds)#, sigma=e)

    except (RuntimeError,TypeError):
        return np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan
        
#     y_initial=gauss_x1(X, *PEAK_initial[0:4])
#     ax1.plot(X,y_initial,'C6',ls="--",marker=",",linewidth=4.,label=r"${\rm Input\ Mole}$",alpha=0.3)
#     y_initial=gauss_x1(X, *PEAK_initial[4:])
#     ax1.plot(X,y_initial,'C6',ls=":",marker=",",linewidth=4.,label=r"${\rm Input\ Skin}$",alpha=0.3)
    
    y_fit_MOLE = gauss_x1(X, *popt[0:4])
#     AX.plot(X,y_fit_MOLE,'k',ls="--",marker=",",linewidth=4.,label=r"${\rm Fit\ Mole}$")
    MOLE_MEAN=popt[1]
    MOLE_SIGMA=popt[2]
    MOLE_AMPLITUDE=popt[0]
    SKIN_MEAN=popt[5]
    SKIN_SIGMA=popt[6]
    SKIN_AMPLITUDE=popt[4]
    
    
    y_fit_SKIN = gauss_x1(X, *popt[4:])
#     AX.plot(X,y_fit_SKIN,'k',ls=":",marker=",",linewidth=4.,label=r"${\rm Fit\ Skin}$")
    
    ## by using the zeroth INTERSECT, we are assuming that the mole is darker and
    ## hence to the left of the skin distribution
    try:
        INTERSECT=np.argwhere(np.diff(np.sign(y_fit_MOLE-y_fit_SKIN))).flatten()[0]
#         AX.plot(X[INTERSECT],y_fit_MOLE[INTERSECT],"ro")
#         AX.fill_between(X[X>X[INTERSECT]],0.,y_fit_SKIN[X>X[INTERSECT]],facecolor="k")
    except:
        INTERSECT=np.nan
#         print("No intersections found -- mole might be quite faint...")
    
#     ax1.plot(X,Y,'C9',marker="o",linewidth=4.,label=r"${\rm Data}$",alpha=0.5)

#     if PLOT_LEG:
#         leg=AX.legend(ncol=2,bbox_to_anchor=(.9, 1.3))
    return INTERSECT,MOLE_MEAN,MOLE_SIGMA,MOLE_AMPLITUDE,SKIN_MEAN,SKIN_SIGMA,SKIN_AMPLITUDE




data_path="/Users/pboorman/Dropbox/1_work/9_projects/9p_molegazer/0_PATIENT_DATA/"   
mole_df=pd.read_csv(data_path+"/0_MASTER_MOLES.csv",converters={'PHOTO': lambda x: str(x)})

mole_df[["red_SKIN",
         "dred_SKIN",
         "AMP_red_SKIN",
         "green_SKIN",
         "dgreen_SKIN",
         "AMP_green_SKIN",
         "blue_SKIN",
         "dblue_SKIN",
         "AMP_blue_SKIN"]]=pd.DataFrame([np.repeat(np.nan,9)], index=mole_df.index)

mole_df[["red_MOLE",
         "dred_MOLE",
         "AMP_red_MOLE",
         "green_MOLE",
         "dgreen_MOLE",
         "AMP_green_MOLE",
         "blue_MOLE",
         "dblue_MOLE",
         "AMP_blue_MOLE"]]=pd.DataFrame([np.repeat(np.nan,9)], index=mole_df.index)



def EXTRACT_MOLE(fits_file):
    IMAGE=fits.open(fits_file)[0].data
    MASK=REGION.to_mask(mode="exact")
    MOLE_DATA=-MASK.cutout(-IMAGE)

    NPIX=int(np.size(MOLE_DATA)/12)
    N,BINS=np.histogram(MOLE_DATA,bins=NPIX)
    BC=(BINS[0:-1]+BINS[1:])/2.
    BC=BC[N>0.];N=N[N>0.]
    return BC,N
        


## this parameter is used to store the region radius required to fit two Gaussians to the mole
mole_df.loc[:,"FIT_REG_RADIUS_PIXELS"]=mole_df.REG_RADIUS_PIXELS
# mole_df=mole_df.tail(1400)
for i,src in mole_df.loc[mole_df.PATIENT_VIEW!="D"].iterrows():
    if i % 5 == 0:print(i)
    PHOTO_PATH=data_path+"/"+str(src.PATIENT)+"/"+str(src.PHOTO)+"/"+str(src.PHOTO)
    for j,BAND in enumerate(["red","green","blue"]):
        
        
        center=PixCoord(x=src.REG_XCENTER_PIXELS,y=src.REG_YCENTER_PIXELS)
        radius=src.REG_RADIUS_PIXELS
        INTER="nan"
        count=0
        while str(INTER)=="nan":
            if count>20:
                print("    Solution not found! May just be a faint mole...")
                break
            radius*=(1.+float(count)*0.05)
            if count>0:print("   Trying with radius "+str(int(100.*float(count)*0.05))+" per cent larger")
                
            REGION=CirclePixelRegion(center,radius)

            BC,N=EXTRACT_MOLE(PHOTO_PATH+"%(BAND)s.fits" %locals())
            INTER,MEAN_MOLE,SIGMA_MOLE,AMPLITUDE_MOLE,MEAN_SKIN,SIGMA_SKIN,AMPLITUDE_SKIN=FIT_GAUSSIAN(BC,N)
    
            if str(INTER)!="nan" and count>0:
                print("    Success! Re-saving region radius...")
                mole_df.loc[mole_df.SCRIPT_ID==i,"FIT_REG_RADIUS_PIXELS"]=radius
            count+=1
                
#         print(INTER)        
        mole_df.loc[mole_df.SCRIPT_ID==i,BAND+"_SKIN"]=MEAN_SKIN
        mole_df.loc[mole_df.SCRIPT_ID==i,"d"+BAND+"_SKIN"]=SIGMA_SKIN
        mole_df.loc[mole_df.SCRIPT_ID==i,"AMP_"+BAND+"_SKIN"]=AMPLITUDE_SKIN
        
        mole_df.loc[mole_df.SCRIPT_ID==i,BAND+"_MOLE"]=MEAN_MOLE
        mole_df.loc[mole_df.SCRIPT_ID==i,"d"+BAND+"_MOLE"]=SIGMA_MOLE
        mole_df.loc[mole_df.SCRIPT_ID==i,"AMP_"+BAND+"_MOLE"]=AMPLITUDE_MOLE
    if count==0:print()
    
print(mole_df.head())
# Out:
# 0
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
# 5
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 10
# 20
# 25
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 30
# 35
# 40
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 45
# 50
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 55
# 60
# 65
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 70
# 75
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 80
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 85
# 90
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 95
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 100
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 105
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 110
# 115
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 120
# 125
# 130
# 135
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 140
# 145
# 150
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 155
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 160
# 165
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 170
# 175
# 180
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 185
# 190
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 195
# 200
# 205
# 210
# 215
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 225
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 230
# 235
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 240
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 245
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 250
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
# 255
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 260
# 265
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 270
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 275
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#    Trying with radius 40 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#    Trying with radius 40 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#     Success! Re-saving region radius...
# 280
# 285
# 290
# 295
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 300
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 305
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 310
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#    Trying with radius 40 per cent larger
#    Trying with radius 45 per cent larger
#    Trying with radius 50 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 315
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 320
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 325
# 330
# 335
# 340
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 345
# 350
# 355
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 360
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 365
# 370
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 375
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
# 380
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 385
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 390
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 395
# 400
# 405
# 410
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 415
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 420
# 425
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 430
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 435
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 440
# 445
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#    Trying with radius 40 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 450
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 455
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 460
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
# 465
# 470
# 475
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 480
# 485
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 490
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#     Success! Re-saving region radius...
# 495
# 500
# 505
# 510
# 515
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 520
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 525
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 530
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 535
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 540
# 545
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 550
# 555
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 560
# 565
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 570
# 575
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 580
# 585
# 590
# 595
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 600
# 605
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 610
# 615
# 620
# 625
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 630
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 635
# 640
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 645
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 650
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 655
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 660
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 665
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 670
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 675
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 680
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 685
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 690
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 695
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 700
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 705
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 710
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 715
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 720
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 725
# 730
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 735
# 740
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#    Trying with radius 40 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 745
# 750
# 755
# 760
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 765
# 770
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 775
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 780
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 785
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 790
# 795
# 800
# 805
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 810
# 815
# 820
# 825
# 830
# 835
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 840
# 845
# 850
# 855
# 860
# 865
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 870
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 875
# 880
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
# 885
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 890
# 895
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 900
# 905
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 910
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 915
# 920
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
# 925
# 930
# 935
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 940
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 945
# 950
# 955
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 960
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 965
# 970
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 975
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 980
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 985
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 990
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#    Trying with radius 40 per cent larger
#     Success! Re-saving region radius...
# 995
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1000
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#     Success! Re-saving region radius...
# 1005
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1010
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1015
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1020
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#    Trying with radius 40 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1025
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1030
# 1035
# 1040
# 1045
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1050
# 1055
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1060
# 1065
# 1070
# 1080
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 1085
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1090
# 1095
# 1105
# 1110
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1115
# 1120
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1125
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1130
# 1135
# 1140
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1145
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1150
# 1155
# 1160
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1165
# 1170
# 1175
# 1180
# 1185
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1190
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1195
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1210
# 1215
# 1220
# 1225
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#    Trying with radius 40 per cent larger
#    Trying with radius 45 per cent larger
#    Trying with radius 50 per cent larger
#    Trying with radius 55 per cent larger
#     Success! Re-saving region radius...
# 1230
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1235
# 1240
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1245
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1250
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
# 1255
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1260
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 1265
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1270
# 1275
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 1280
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1285
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1290
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1295
# 1300
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1305
# 1310
# 1315
# 1320
# 1325
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1330
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1335
# 1340
# 1345
# 1350
# 1355
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 1360
# 1365
# 1370
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1375
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1380
# 1385
# 1390
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1395
# 1400
# 1405
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1410
# 1415
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1420
# 1425
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1430
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
# 1435
# 1440
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 1445
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1450
# 1455
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1460
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1465
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1470
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1475
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1480
# 1485
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1490
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1495
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1500
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1505
# 1510
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1515
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1520
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1525
# 1530
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 1535
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1540
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1545
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1560
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1565
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 1570
# 1575
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1580
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1585
# 1590
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1595
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1600
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 1605
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1610
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1615
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 1620
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1625
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 1630
# ...
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 3675
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3680
# 3685
# 3690
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 3695
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3700
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3705
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 3710
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3715
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3720
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3725
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3730
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3735
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3740
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3745
# 3750
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3755
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3760
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3765
# 3770
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3775
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3780
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 3785
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#     Success! Re-saving region radius...
# 3790
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3795
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3800
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 3805
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3810
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3815
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3820
# 3825
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#    Trying with radius 35 per cent larger
#    Trying with radius 40 per cent larger
#    Trying with radius 45 per cent larger
#    Trying with radius 50 per cent larger
#    Trying with radius 55 per cent larger
#    Trying with radius 60 per cent larger
#    Trying with radius 65 per cent larger
#     Success! Re-saving region radius...
# 3830
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3835
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3840
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3845
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3850
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3855
# 3860
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3865
# 3870
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#    Trying with radius 25 per cent larger
#    Trying with radius 30 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3875
# 3880
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 3885
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3890
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3895
# 3900
# 3905
# 3910
# 3915
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 3920
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3925
# 3930
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#    Trying with radius 20 per cent larger
#     Success! Re-saving region radius...
# 3935
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3940
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3945
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3950
# 3955
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3960
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3965
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3970
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#    Trying with radius 15 per cent larger
#     Success! Re-saving region radius...
# 3975
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
# 3980
# 3985
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3990
#    Trying with radius 5 per cent larger
#    Trying with radius 10 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 3995
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 4000
#    Trying with radius 5 per cent larger
#     Success! Re-saving region radius...
# 4005
#    SCRIPT_ID          MOLE_ID PATIENT  PHOTO  REG_RADIUS_PIXELS  \
# 0          0  A_30536_POS02_1       A  30536          60.735346
# 1          1  A_30536_POS02_2       A  30536          24.238328
# 2          2  A_30536_POS02_3       A  30536          18.615205
# 3          3  A_30536_POS02_4       A  30536          24.238328
# 4          4  A_30536_POS02_5       A  30536          24.238328
#
#    REG_XCENTER_PIXELS  REG_YCENTER_PIXELS REG_SHAPE PATIENT_VIEW    OBS_DATE  \
# 0           1083.1920           2676.5440    CIRCLE            2  18/01/2019
# 1           1049.7081           1326.3129    CIRCLE            2  18/01/2019
# 2           1140.1920           2312.5440    CIRCLE            2  18/01/2019
# 3           1209.2160           3122.6112    CIRCLE            2  18/01/2019
# 4           2300.9548           2216.3750    CIRCLE            2  18/01/2019
#
#    ...    red_MOLE  dred_MOLE  AMP_red_MOLE  green_MOLE  dgreen_MOLE  \
# 0  ...  187.155649 -11.387314    124.055815  153.878991    18.142984
# 1  ...  166.650604   7.848831     14.866259  122.363093     8.714699
# 2  ...  180.423532  -6.668945     12.164453  142.270318   -12.310191
# 3  ...  202.229616   2.628929     90.289737  165.133549     6.444320
# 4  ...  185.573440  -1.487014     55.865555  157.945086     7.972051
#
#    AMP_green_MOLE   blue_MOLE  dblue_MOLE  AMP_blue_MOLE  \
# 0       99.067073  133.758188   16.928662      95.745251
# 1        7.514588  115.807941  -20.817677       6.991326
# 2        8.559708  119.605653   15.549648       6.485293
# 3       15.104020  153.737557    1.117171     228.096730
# 4       27.741540  140.123467   -5.745014      20.564241
#
#    FIT_REG_RADIUS_PIXELS
# 0              60.735346
# 1              25.450244
# 2              18.615205
# 3              48.291839
# 4              24.238328
#
# [5 rows x 29 columns]

# %%
mole_df.to_csv("/Users/pboorman/Dropbox/moles_with_photometry.csv")

# %% [markdown]
# ## Now plot figure for each mole in R, G and B (on same plot)

# %% [markdown]
# Try on one mole:

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from regions import read_ds9,write_ds9,PixCoord,BoundingBox,CirclePixelRegion
from astropy.io import fits
from astropy.stats import SigmaClip
import palettable.colorbrewer as pc
from cycler import cycler
from scipy.optimize import curve_fit
from astropy.stats import SigmaClip
from collections import OrderedDict

plt.rcParams["axes.prop_cycle"]=cycler('color',pc.qualitative.Set3_12.mpl_colors)
# %matplotlib inline

data_path=os.getcwd()+"/0_PATIENT_DATA/"   
mole_df=pd.read_csv(data_path+"/0_MASTER_MOLES.csv",converters={'PHOTO': lambda x: str(x)})


## filter moles that photometry could not be extracted for
legit_moles=mole_df.dropna(subset=["red_SKIN",
                                   "dred_SKIN",
                                   "AMP_red_SKIN",
                                   "green_SKIN",
                                   "dgreen_SKIN",
                                   "AMP_green_SKIN",
                                   "blue_SKIN",
                                   "dblue_SKIN",
                                   "AMP_blue_SKIN",
                                   "red_MOLE",
                                   "dred_MOLE",
                                   "AMP_red_MOLE",
                                   "green_MOLE",
                                   "dgreen_MOLE",
                                   "AMP_green_MOLE",
                                   "blue_MOLE",
                                   "dblue_MOLE",
                                   "AMP_blue_MOLE"])

print(len(legit_moles))
# Out:
# 3920

# %% [markdown]
# Insert leading zeros by hand
#
# (Warning: takes a while!)

# %%
patient="F"
photo="29010"
mole="10"


## BE CAREFUL -- currently just inserting leading zeros by hand to photo names with > 5 characters
def LEADING_ZEROS(row):
    if len(row["PHOTO"]) > 5:
        return (row["PHOTO"]).zfill(8)
    else:
        return row["PHOTO"]


legit_moles.loc[:,"PHOTO"]=legit_moles.apply(LEADING_ZEROS, axis=1)
legit_moles.loc[:,"PHOTO_PATH"]=data_path+"/"+legit_moles.PATIENT+"/"+legit_moles.PHOTO+"/"+legit_moles.PHOTO

mole_ID="I_39130_POS15_9"
MOLE=legit_moles.loc[(legit_moles.MOLE_ID==mole_ID)]
print(MOLE.SCRIPT_ID)

## use this to start the figure generation on a particular mole (i.e. miss out the ones that figures have already been generated for)
legit_moles=legit_moles.loc[(legit_moles.SCRIPT_ID>1261)]
print(len(legit_moles))
# Out:
# 1262    1262
# Name: SCRIPT_ID, dtype: int64
# 2701

# %%
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.image as mpimg
import matplotlib.patches as patches
import numpy as np



def gauss_x1(x, *p):
    a1, b1, c1, d1=p
    y = a1*np.exp(-np.power((x - b1), 2.)/(2. * c1**2.))# + d1
    return y


def FIND_INSET_LOC(xc,yc,xhalf,yhalf):
    if xc < xhalf and yc < yhalf:
        location="upper right"
    elif xc < xhalf and yc > yhalf:
        location="lower right"
    elif xc > xhalf and yc < yhalf:
        location="upper left"
    else:
        location="lower left"
    
    return location

def ZOOM_IN_RECT(input,AX,ZOOM,rect,cmap):
    x1, x2, y1, y2 = rect.get_x(), rect.get_x()+rect.get_width(),rect.get_y(), rect.get_y()+rect.get_height() # specify the limits
    
    LOC=FIND_INSET_LOC((x1+x2)/2.,(y1+y2)/2.,np.shape(input)[1]/2.,np.shape(input)[0]/2.)
    axins=zoomed_inset_axes(AX,ZOOM,loc=LOC)#bbox_to_anchor=(0.7,0.9),bbox_transform=AX.transAxes, loc=3, borderpad=0)
    
    axins.set_xlim(x1, x2)  # apply the x-limits
    axins.set_ylim(y1, y2)  # apply the y-limits
    mark_inset(AX, axins, loc1=3, loc2=4, fc="none", ec="1.")
    plt.yticks(visible=False)
    plt.xticks(visible=False)
    # flip image
    rot = np.flipud(input)
    axins.imshow(input, cmap=cmap,zorder=10**6)
    for spine in axins.spines.values():
        spine.set_edgecolor('white')
        spine.set_linewidth(4.)



for i,MOLE in legit_moles.iterrows():
    fig=plt.figure(figsize=(28,12))
    gs=gridspec.GridSpec(3,7)
    gs.update(left=0.,right=1.,bottom=0.,top=0.98,wspace=0.07,hspace=0.025)
    ax_huma=fig.add_subplot(gs[0:3,0:3])

    for j,band in enumerate(["red","green","blue"]):
        ax_data=fig.add_subplot(gs[j,3])
        ax_hist=fig.add_subplot(gs[j,4:6])
        ax_filt=fig.add_subplot(gs[j,6])

        PRELIM_DATA=fits.open(str(MOLE.PHOTO_PATH)+band+".fits")[0].data
        REG=CirclePixelRegion(PixCoord(x=float(MOLE.REG_XCENTER_PIXELS), y=float(MOLE.REG_YCENTER_PIXELS)), radius=float(MOLE.FIT_REG_RADIUS_PIXELS))
        MASK=REG.to_mask(mode="exact")
        MOLE_DATA=MASK.cutout(PRELIM_DATA)
        NPIX=int(np.size(MOLE_DATA)/12)
        N,BINS=np.histogram(MOLE_DATA,bins=NPIX)
        CENTER_PIXEL=(MOLE_DATA[int(len(MOLE_DATA)/2),int(len(MOLE_DATA)/2)])
        BC=(BINS[0:-1]+BINS[1:])/2.
        BC=BC[N>0.];N=N[N>0.]

        y_fit_MOLE=gauss_x1(BC,MOLE["AMP_"+band+"_MOLE"],MOLE[band+"_MOLE"],MOLE["d"+band+"_MOLE"],0.)
        y_fit_SKIN=gauss_x1(BC,MOLE["AMP_"+band+"_SKIN"],MOLE[band+"_SKIN"],MOLE["d"+band+"_SKIN"],0.)

        FILTERED=MOLE_DATA
        

        image=mpimg.imread(str(MOLE.PHOTO_PATH)+"ORIGINAL.jpg")[::-1]
        ax_huma.imshow(image)
        ax_huma.set_ylim(ax_huma.get_ylim()[::-1])
        artist=REG.as_artist()
#         ax_huma.add_artist(artist)
        lower_corner=(float(MOLE.REG_XCENTER_PIXELS)-float(MOLE.REG_RADIUS_PIXELS),float(MOLE.REG_YCENTER_PIXELS)-float(MOLE.REG_RADIUS_PIXELS))
        rect1 = patches.Rectangle(lower_corner,float(MOLE.REG_RADIUS_PIXELS)*2.,float(MOLE.REG_RADIUS_PIXELS)*2.,linewidth=3, edgecolor='r', facecolor='none')
        ZOOM_FACTOR=500./float(MOLE.REG_RADIUS_PIXELS)
        ZOOM_IN_RECT(image,ax_huma,ZOOM_FACTOR,rect1,cmap='gray')
        ax_huma.set_xlabel(r"$x$")
        ax_huma.set_ylabel(r"$y$")



        ax_data.imshow(-MOLE_DATA,interpolation='nearest', origin='lower',extent=MASK.bbox.extent,cmap="Greys")
        ax_data.set_xlabel(r"$x$")
        ax_data.set_ylabel(r"$y$")
        for tick in ax_data.get_xticklabels():
            tick.set_rotation(45)
        for tick in ax_data.get_yticklabels():
            tick.set_rotation(45)

        ax_hist.plot(BC,y_fit_MOLE,'k',ls="--",marker=",",linewidth=4.,label=r"${\rm Fit\ Mole}$")
        ax_hist.plot(BC,y_fit_SKIN,'k',ls=":",marker=",",linewidth=4.,label=r"${\rm Fit\ Skin}$")
        ax_hist.plot(BC,N,ls='steps-mid',c=band,alpha=0.5)
        
        try:
            INTER=np.argwhere(np.diff(np.sign(y_fit_MOLE-y_fit_SKIN))).flatten()[0]
            ax_hist.fill_between(BC[BC>BC[INTER]],0.,N[BC>BC[INTER]],facecolor="0.7",zorder=-1)
            FILTERED[MOLE_DATA>BC[INTER]]=0.
            ax_filt.imshow(-FILTERED,
                           interpolation='nearest', origin='lower',
                           extent=MASK.bbox.extent,cmap="Greys",vmin=-BC[INTER],vmax=-np.min(BC))
        except IndexError:
            print("No intersect found?")
        ax_hist.set_xlim(0.,255.)#np.min(TIME),np.max(TIME))
        ax_hist.set_ylim(0.,np.max(N)*1.02)
        ax_hist.set_yticklabels([])
        ax_hist.set_xlabel(r"${\rm Brightness}$")
        for tick in ax_hist.get_xticklabels():
            tick.set_rotation(45)

        ax_filt.yaxis.tick_right()
        ax_filt.yaxis.set_label_position("right")
        ax_filt.yaxis.set_ticks_position('both')

        ax_filt.set_xlabel(r"$x$")
        ax_filt.set_ylabel(r"$y$")
        for tick in ax_filt.get_xticklabels():
            tick.set_rotation(45)
        for tick in ax_filt.get_yticklabels():
            tick.set_rotation(45)

        if int(j)<2:
            ax_data.set_xticklabels([])
            ax_hist.set_xticklabels([])
            ax_filt.set_xticklabels([])

    TITLE="Patient: "+str(MOLE.PATIENT)+", Photo: "+str(MOLE.PHOTO)+", Mole: "+str(int(MOLE.SCRIPT_ID)+1)+"/"+str(len(legit_moles))+", Date: "+str(MOLE.OBS_DATE)
    fig.text(0.5,1.03,TITLE,ha='center',va='bottom',fontsize=60.,color='k')
    MOLE_NAME=MOLE.MOLE_ID
    print(MOLE_NAME)
    fig.savefig(data_path+"/MOLE_PHOTOMETRY/"+MOLE_NAME+".png")
    plt.close()
# Out:
# F_79946_POS11_8
# F_79946_POS11_9
# F_79947_POS09_1
# F_79947_POS09_2
# F_79947_POS09_3
# F_79947_POS09_4
# F_79947_POS09_5
# F_79947_POS09_6
# F_79947_POS09_7
# F_79948_POS12_1
# F_79948_POS12_2
# F_79948_POS12_3
# F_79948_POS12_4
# F_79948_POS12_5
# F_79949_POS10_1
# F_79949_POS10_2
# F_79949_POS10_3
# F_79949_POS10_4
# F_79949_POS10_5
# F_79949_POS10_6
# F_79949_POS10_7
# F_79949_POS10_8
# F_79949_POS10_9
# F_79950_POS05_1
# F_79950_POS05_2
# F_79950_POS05_3
# F_79950_POS05_4
# F_79950_POS05_5
# F_79950_POS05_6
# F_79950_POS05_7
# F_79950_POS05_8
# F_79950_POS05_9
# F_79951_POS06_1
# F_79951_POS06_2
# F_79951_POS06_3
# F_79951_POS06_4
# F_79951_POS06_5
# F_79951_POS06_6
# F_79951_POS06_7
# F_79951_POS06_8
# F_79951_POS06_9
# F_79951_POS06_10
# F_79952_POS07_1
# F_79952_POS07_2
# F_79952_POS07_3
# F_79952_POS07_4
# F_79952_POS07_5
# F_79952_POS07_6
# F_79953_POS08_1
# F_79953_POS08_2
# F_79953_POS08_3
# F_79953_POS08_4
# F_79953_POS08_5
# G_28834_POS01_1
# G_28834_POS01_2
# G_28834_POS01_3
# G_28834_POS01_4
# G_28834_POS01_5
# G_28834_POS01_6
# G_28834_POS01_7
# G_28834_POS01_8
# G_28834_POS01_9
# G_28834_POS01_10
# G_28834_POS01_11
# G_28834_POS01_12
# G_28834_POS01_13
# G_28835_POS02_1
# G_28835_POS02_2
# G_28835_POS02_3
# G_28835_POS02_4
# G_28835_POS02_5
# G_28835_POS02_6
# G_28835_POS02_7
# G_28835_POS02_8
# G_28835_POS02_9
# G_28835_POS02_10
# G_28835_POS02_11
# G_28835_POS02_12
# G_28836_POS03_1
# G_28836_POS03_2
# G_28836_POS03_3
# G_28836_POS03_4
# G_28836_POS03_5
# G_28836_POS03_6
# G_28836_POS03_7
# G_28837_POS04_1
# G_28837_POS04_2
# G_28837_POS04_3
# G_28837_POS04_4
# G_28837_POS04_5
# G_28837_POS04_6
# G_28838_POS15_1
# G_28838_POS15_2
# G_28838_POS15_3
# G_28838_POS15_4
# G_28838_POS15_5
# G_28838_POS15_6
# G_28838_POS15_7
# G_28838_POS15_8
# G_28838_POS15_9
# G_28838_POS15_10
# G_28839_POS16_1
# G_28839_POS16_2
# G_28839_POS16_3
# G_28839_POS16_4
# G_28839_POS16_5
# G_28839_POS16_6
# G_28839_POS16_7
# G_28839_POS16_8
# G_28839_POS16_9
# G_28840_POS09_1
# G_28840_POS09_2
# G_28840_POS09_3
# G_28840_POS09_4
# G_28840_POS09_5
# G_28841_POS11_1
# G_28841_POS11_2
# G_28841_POS11_3
# G_28841_POS11_4
# G_28841_POS11_5
# G_28842_POS12_1
# G_28842_POS12_2
# G_28842_POS12_3
# G_28842_POS12_4
# G_28842_POS12_5
# G_28842_POS12_6
# G_28842_POS12_7
# G_28842_POS12_8
# G_28842_POS12_9
# G_28842_POS12_10
# G_28842_POS12_11
# G_28842_POS12_12
# G_28842_POS12_13
# G_28842_POS12_14
# G_28842_POS12_15
# G_28842_POS12_16
# G_28842_POS12_17
# G_28842_POS12_18
# G_28842_POS12_19
# G_28842_POS12_20
# G_28842_POS12_21
# G_28842_POS12_22
# G_28842_POS12_23
# G_28842_POS12_24
# G_28842_POS12_25
# G_28842_POS12_26
# G_28842_POS12_27
# G_28842_POS12_28
# G_28843_POS10_1
# G_28843_POS10_2
# G_28843_POS10_3
# G_28843_POS10_4
# G_28843_POS10_5
# G_28843_POS10_6
# G_28843_POS10_7
# G_28843_POS10_8
# G_28843_POS10_9
# G_28844_POS06_1
# G_28844_POS06_2
# G_28844_POS06_3
# G_28844_POS06_4
# G_28844_POS06_5
# G_28845_POS05_1
# G_28845_POS05_2
# G_28845_POS05_3
# G_28845_POS05_4
# G_28845_POS05_5
# G_28845_POS05_6
# G_28845_POS05_7
# G_28845_POS05_8
# G_28845_POS05_9
# G_28845_POS05_10
# G_28845_POS05_11
# G_28845_POS05_12
# G_28845_POS05_13
# G_28845_POS05_14
# G_28846_POS08_1
# G_28846_POS08_2
# G_28846_POS08_3
# G_28846_POS08_4
# G_28846_POS08_5
# G_28846_POS08_6
# G_28846_POS08_7
# G_28846_POS08_8
# G_28846_POS08_9
# G_28846_POS08_10
# G_28847_POS07_1
# G_28847_POS07_2
# G_28847_POS07_3
# G_28847_POS07_4
# G_28847_POS07_5
# G_28847_POS07_6
# G_28848_POS01Z_1
# G_28848_POS01Z_2
# G_28848_POS01Z_3
# G_28848_POS01Z_4
# G_28848_POS01Z_5
# G_28848_POS01Z_6
# G_28848_POS01Z_7
# G_28848_POS01Z_8
# G_28848_POS01Z_9
# G_28848_POS01Z_10
# G_28850_POS08Z_1
# G_28850_POS08Z_2
# G_28850_POS08Z_3
# G_28850_POS08Z_4
# G_28850_POS08Z_5
# G_28850_POS08Z_6
# G_28850_POS08Z_7
# G_28850_POS08Z_8
# G_28850_POS08Z_9
# G_28850_POS08Z_10
# G_28850_POS08Z_11
# G_28850_POS08Z_12
# G_28850_POS08Z_13
# G_28852_POS02Z_1
# G_28852_POS02Z_2
# G_28852_POS02Z_3
# G_28852_POS02Z_4
# G_28852_POS02Z_5
# G_28852_POS02Z_6
# G_28852_POS02Z_7
# G_28852_POS02Z_8
# G_28852_POS02Z_9
# G_28852_POS02Z_10
# G_28852_POS02Z_11
# G_28852_POS02Z_12
# G_28852_POS02Z_13
# G_28852_POS02Z_14
# G_28852_POS02Z_15
# G_28852_POS02Z_16
# G_28852_POS02Z_17
# H_39158_POS01_1
# H_39158_POS01_2
# H_39158_POS01_3
# H_39158_POS01_4
# H_39158_POS01_5
# H_39158_POS01_6
# H_39159_POS02_1
# H_39159_POS02_2
# H_39159_POS02_3
# H_39159_POS02_4
# H_39159_POS02_5
# H_39159_POS02_6
# H_39159_POS02_7
# H_39159_POS02_8
# H_39159_POS02_9
# H_39159_POS02_10
# H_39165_POS03_1
# H_39165_POS03_2
# H_39165_POS03_3
# H_39165_POS03_4
# H_39165_POS03_5
# H_39165_POS03_6
# H_39165_POS03_7
# H_39165_POS03_8
# H_39166_POS16_1
# H_39166_POS16_2
# H_39166_POS16_3
# H_39166_POS16_4
# H_39166_POS16_5
# H_39167_POS04_1
# H_39167_POS04_2
# H_39167_POS04_3
# H_39167_POS04_4
# H_39168_POS15_1
# H_39168_POS15_2
# H_39168_POS15_3
# H_39168_POS15_4
# H_39168_POS15_5
# H_39168_POS15_6
# H_39168_POS15_7
# H_39168_POS15_8
# H_39168_POS15_9
# H_39169_POS09_1
# H_39169_POS09_2
# H_39170_POS11_1
# H_39170_POS11_2
# H_39171_POS12_1
# H_39171_POS12_2
# H_39172_POS10_1
# H_39172_POS10_2
# H_39172_POS10_3
# H_39172_POS10_4
# H_39173_POS05_1
# H_39173_POS05_2
# H_39173_POS05_3
# H_39173_POS05_4
# H_39173_POS05_5
# H_39173_POS05_6
# H_39174_POS06_1
# H_39174_POS06_2
# H_39175_POS07_1
# H_39175_POS07_2
# H_39175_POS07_3
# H_39175_POS07_4
# H_39175_POS07_5
# H_39176_POS08_1
# H_39176_POS08_2
# H_39176_POS08_3
# I_39116_POS01_1
# I_39116_POS01_2
# I_39116_POS01_3
# I_39116_POS01_4
# I_39116_POS01_5
# I_39116_POS01_6
# I_39116_POS01_7
# I_39116_POS01_8
# I_39116_POS01_9
# I_39116_POS01_10
# I_39116_POS01_11
# I_39116_POS01_12
# I_39116_POS01_13
# I_39116_POS01_14
# I_39116_POS01_15
# I_39116_POS01_16
# I_39116_POS01_17
# I_39116_POS01_18
# I_39116_POS01_19
# I_39116_POS01_20
# I_39116_POS01_21
# I_39116_POS01_22
# I_39116_POS01_23
# I_39116_POS01_24
# I_39117_POS02_1
# I_39117_POS02_2
# I_39117_POS02_3
# I_39117_POS02_4
# I_39117_POS02_5
# I_39117_POS02_6
# I_39117_POS02_7
# I_39117_POS02_8
# I_39117_POS02_9
# I_39117_POS02_10
# I_39117_POS02_11
# I_39117_POS02_12
# I_39117_POS02_13
# I_39117_POS02_14
# I_39117_POS02_15
# I_39117_POS02_16
# I_39117_POS02_17
# I_39117_POS02_18
# I_39117_POS02_19
# I_39126_POS04_1
# I_39126_POS04_2
# I_39126_POS04_3
# I_39126_POS04_4
# I_39126_POS04_5
# I_39126_POS04_6
# I_39126_POS04_7
# I_39126_POS04_8
# I_39126_POS04_9
# I_39126_POS04_10
# I_39126_POS04_11
# I_39126_POS04_12
# I_39126_POS04_13
# I_39126_POS04_14
# I_39126_POS04_15
# I_39127_POS15_1
# I_39127_POS15_2
# I_39127_POS15_3
# I_39127_POS15_4
# I_39127_POS15_5
# I_39127_POS15_6
# I_39127_POS15_7
# I_39127_POS15_8
# I_39127_POS15_9
# I_39128_POS03_1
# I_39128_POS03_2
# I_39128_POS03_3
# I_39128_POS03_4
# I_39128_POS03_5
# I_39128_POS03_6
# I_39128_POS03_7
# I_39128_POS03_8
# I_39128_POS03_9
# I_39128_POS03_10
# I_39128_POS03_11
# I_39128_POS03_12
# I_39128_POS03_13
# I_39128_POS03_14
# I_39128_POS03_15
# I_39128_POS03_16
# I_39128_POS03_17
# I_39129_POS16_1
# I_39129_POS16_2
# I_39129_POS16_3
# I_39129_POS16_4
# I_39129_POS16_5
# I_39129_POS16_6
# I_39129_POS16_7
# I_39130_POS15_1
# I_39130_POS15_2
# I_39130_POS15_3
# I_39130_POS15_4
# I_39130_POS15_5
# I_39130_POS15_6
# I_39130_POS15_7
# I_39130_POS15_8
# I_39130_POS15_9
